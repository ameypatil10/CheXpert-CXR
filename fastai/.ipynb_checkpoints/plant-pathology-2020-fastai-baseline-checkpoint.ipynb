# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import pandas as pd
import numpy as np
from fastai.vision import *
from fastai.metrics import error_rate

torch.manual_seed(121)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(121)

# %%
df = pd.read_csv('../input/plant-pathology-2020-fgvc7/train.csv')
labels = np.array(df.iloc[:, 1:])
labels = np.where(labels==1)[1]

df['label'] = labels
df.to_csv('./train_data.csv', index=False)

# %%
BS = 32
IMG_SZ = 512
CLASS_WT = torch.FloatTensor([1.0, 1.0, 1.0, 1.0])

GPU_IDS = [0,1,2]
torch.cuda.set_device(0)

label_dict = {0: 'healthy',
              1: 'multiple_diseases',
              2: 'rust',
              3: 'scab',
              'micro': 'micro',
              'macro': 'macro',
             }

# %%
data_tfms = get_transforms(do_flip=True, flip_vert=True, max_rotate=None, max_zoom=1, max_lighting=None,
                          max_warp=0, p_affine=0, p_lighting=0)

data = ImageDataBunch.from_csv('../input/plant-pathology-2020-fgvc7', csv_labels='../../working/train_data.csv', folder='images', 
                               label_col=5, suffix='.jpg', valid_pct=0.2, ds_tfms=data_tfms,
                               bs=BS, size=IMG_SZ).normalize(imagenet_stats)
data.show_batch(rows=3, figsize=(7,6))

# %%
print(data.train_ds)
print(data.valid_ds)
# Out:
# LabelList (1548 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# 3,1,0,0,0
# Path: ../input/plant-pathology-2020-fgvc7
# LabelList (273 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# 2,0,2,2,2
# Path: ../input/plant-pathology-2020-fgvc7

# %%
from sklearn.metrics import roc_curve, auc
class AUC(Callback):

    def __init__(self, num_cl, pick='micro'):
        self.id_to_class = label_dict
        self.name = str(self.id_to_class[pick])+'-AUC'
        self.pick = pick
        self.num_cl = num_cl
        
    
    def on_epoch_begin(self, **kwargs):
        self.outputs, self.targets = [], []
    
    def on_batch_end(self, last_output, last_target, **kwargs):
        self.outputs.append(last_output)
        self.targets.append(last_target)
    
    def on_epoch_end(self, last_metrics, **kwargs):
        self.outputs = F.softmax(torch.cat(self.outputs), dim=1).cpu().detach().numpy()
        self.targets = torch.cat(self.targets).cpu().numpy().reshape(-1)
        self.targets = np.eye(self.num_cl)[self.targets]
        fpr, tpr, roc_auc = {}, {}, {}
        for i in range(self.num_cl):
          fpr[i], tpr[i], _ = roc_curve(self.targets[:, i], self.outputs[:, i])
          roc_auc[self.id_to_class[i]] = auc(fpr[i], tpr[i])
        
        # Compute micro-average ROC curve and ROC area
        fpr["micro"], tpr["micro"], _ = roc_curve(self.targets.ravel(), self.outputs.ravel())
        roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
        all_fpr = np.unique(np.concatenate([fpr[i] for i in range(self.num_cl)]))

        # Then interpolate all ROC curves at this points
        mean_tpr = np.zeros_like(all_fpr)
        for i in range(self.num_cl):
            mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

        # Finally average it and compute AUC
        mean_tpr /= self.num_cl

        fpr["macro"] = all_fpr
        tpr["macro"] = mean_tpr
        roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
        return add_metrics(last_metrics, roc_auc[self.id_to_class[self.pick]])

# %%
# !pip install efficientnet_pytorch
from efficientnet_pytorch import EfficientNet

model_name = 'efficientnet-b3'
def getModel():
    model = EfficientNet.from_pretrained(model_name)
#     model._bn1 = nn.Identity()
    model._fc = nn.Linear(1536,data.c)
    return model
# Out:
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.6.3.tar.gz (16 kB)
# Requirement already satisfied: torch in /opt/conda/lib/python3.6/site-packages (from efficientnet_pytorch) (1.4.0)
# Building wheels for collected packages: efficientnet-pytorch
# done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.6.3-py3-none-any.whl size=12419 sha256=6057696b595c117d8bda22948af72ea44079fc652e4dfcc8ffa108948512b070
#   Stored in directory: /root/.cache/pip/wheels/1c/07/d1/ff77968842daae1dde944173a8e8a7be193646d37842f13b24
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.6.3

# %%
learn = Learner(data, getModel(), model_dir='/kaggle/working/',
                    metrics=[accuracy, AUC(num_cl=4, pick=0), AUC(num_cl=4, pick=1), AUC(num_cl=4, pick=2), AUC(num_cl=4, pick=3), AUC(num_cl=4, pick='macro')])
# learn.loss_func = nn.CrossEntropyLoss(weight=CLASS_WT)
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b3-5fb5a3c3.pth" to /root/.cache/torch/checkpoints/efficientnet-b3-5fb5a3c3.pth
# HBox(children=(FloatProgress(value=0.0, max=49388949.0), HTML(value='')))
# Loaded pretrained weights for efficientnet-b3

# %%
# preds,y,losses = learn.get_preds(with_loss=True)
# interp = ClassificationInterpretation(learn, preds, y, losses)
# interp.plot_top_losses(9, figsize=(15,11))
# interp.plot_confusion_matrix(figsize=(6,6), dpi=60)

# %%
learn.unfreeze()

learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>healthy-AUC</th>
#       <th>multiple_diseases-AUC</th>
#       <th>rust-AUC</th>
#       <th>scab-AUC</th>
#       <th>macro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='85' class='' max='96', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       88.54% [85/96 03:36<00:28 4.3798]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5, max_lr=1e-3)
learn.save('draft-efficientnet-B3')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>healthy-AUC</th>
#       <th>multiple_diseases-AUC</th>
#       <th>rust-AUC</th>
#       <th>scab-AUC</th>
#       <th>macro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.721941</td>
#       <td>0.930931</td>
#       <td>0.879121</td>
#       <td>0.984589</td>
#       <td>0.907060</td>
#       <td>0.980831</td>
#       <td>0.988861</td>
#       <td>0.968816</td>
#       <td>05:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.625512</td>
#       <td>2.543175</td>
#       <td>0.813187</td>
#       <td>0.990274</td>
#       <td>0.540265</td>
#       <td>0.982846</td>
#       <td>0.989487</td>
#       <td>0.882014</td>
#       <td>05:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.466583</td>
#       <td>0.968100</td>
#       <td>0.619048</td>
#       <td>0.982945</td>
#       <td>0.753447</td>
#       <td>0.985379</td>
#       <td>0.990426</td>
#       <td>0.933012</td>
#       <td>05:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.296247</td>
#       <td>0.365938</td>
#       <td>0.926740</td>
#       <td>0.996712</td>
#       <td>0.931605</td>
#       <td>0.989984</td>
#       <td>0.996058</td>
#       <td>0.981131</td>
#       <td>05:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.229813</td>
#       <td>0.285924</td>
#       <td>0.941392</td>
#       <td>0.997329</td>
#       <td>0.940706</td>
#       <td>0.992114</td>
#       <td>0.997935</td>
#       <td>0.985651</td>
#       <td>05:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
# learn.fit_one_cycle(2, max_lr=1e-3)
# learn.save('draft-efficientnet-B3')

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>healthy-AUC</th>
#       <th>multiple_diseases-AUC</th>
#       <th>rust-AUC</th>
#       <th>scab-AUC</th>
#       <th>macro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='68' class='' max='96', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       70.83% [68/96 03:09<01:17 0.3231]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze()
learn.fit_one_cycle(4, max_lr=1e-4)
learn.save('draft-efficientnet-B3')
learn.recorder.plot_losses()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>healthy-AUC</th>
#       <th>multiple_diseases-AUC</th>
#       <th>rust-AUC</th>
#       <th>scab-AUC</th>
#       <th>macro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.169304</td>
#       <td>0.247727</td>
#       <td>0.937729</td>
#       <td>0.997123</td>
#       <td>0.952841</td>
#       <td>0.992286</td>
#       <td>0.997872</td>
#       <td>0.987300</td>
#       <td>05:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.234748</td>
#       <td>0.261455</td>
#       <td>0.952381</td>
#       <td>0.997534</td>
#       <td>0.966906</td>
#       <td>0.993380</td>
#       <td>0.998373</td>
#       <td>0.990679</td>
#       <td>05:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.163198</td>
#       <td>0.237108</td>
#       <td>0.948718</td>
#       <td>0.998356</td>
#       <td>0.970767</td>
#       <td>0.994762</td>
#       <td>0.999124</td>
#       <td>0.992399</td>
#       <td>05:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.133277</td>
#       <td>0.230282</td>
#       <td>0.948718</td>
#       <td>0.998082</td>
#       <td>0.972973</td>
#       <td>0.994589</td>
#       <td>0.999124</td>
#       <td>0.992823</td>
#       <td>05:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>healthy-AUC</th>
#       <th>multiple_diseases-AUC</th>
#       <th>rust-AUC</th>
#       <th>scab-AUC</th>
#       <th>macro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='58' class='' max='96', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.42% [58/96 02:40<01:45 0.1121]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze()
learn.fit_one_cycle(4, max_lr=1e-6)
learn.save('final-efficientnet-B3')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>healthy-AUC</th>
#       <th>multiple_diseases-AUC</th>
#       <th>rust-AUC</th>
#       <th>scab-AUC</th>
#       <th>macro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.125263</td>
#       <td>0.228819</td>
#       <td>0.948718</td>
#       <td>0.998014</td>
#       <td>0.972146</td>
#       <td>0.994531</td>
#       <td>0.999124</td>
#       <td>0.992436</td>
#       <td>05:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.112596</td>
#       <td>0.228532</td>
#       <td>0.948718</td>
#       <td>0.997877</td>
#       <td>0.972421</td>
#       <td>0.994647</td>
#       <td>0.999124</td>
#       <td>0.992642</td>
#       <td>04:59</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.138735</td>
#       <td>0.228330</td>
#       <td>0.948718</td>
#       <td>0.998014</td>
#       <td>0.972146</td>
#       <td>0.994704</td>
#       <td>0.999124</td>
#       <td>0.992532</td>
#       <td>05:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.124662</td>
#       <td>0.226504</td>
#       <td>0.948718</td>
#       <td>0.998014</td>
#       <td>0.972973</td>
#       <td>0.994647</td>
#       <td>0.999186</td>
#       <td>0.992602</td>
#       <td>05:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_df = pd.read_csv('../input/plant-pathology-2020-fgvc7/test.csv')

# %%
test = ImageList.from_df(test_df, '../input/plant-pathology-2020-fgvc7/images/', suffix='.jpg')
data.add_test(test)
print(data)
# Out:
# ImageDataBunch;
#
# Train: LabelList (1548 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# 3,1,0,0,0
# Path: ../input/plant-pathology-2020-fgvc7;
#
# Valid: LabelList (273 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# 2,0,2,2,2
# Path: ../input/plant-pathology-2020-fgvc7;
#
# Test: LabelList (1821 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: EmptyLabelList
# ,,,,
# Path: ../input/plant-pathology-2020-fgvc7

# %%
preds, *_ = learn.get_preds(ds_type=DatasetType.Test)

# %%
sub = pd.read_csv('../input/plant-pathology-2020-fgvc7/sample_submission.csv')
for lbl in range(4): 
    sub[[label_dict[lbl]]] = preds.detach().numpy()[:, lbl]
sub.head
# Out:
# <bound method NDFrame.head of        image_id   healthy  multiple_diseases      rust      scab
# 0        Test_0  0.000389           0.019584  0.979880  0.000147
# 1        Test_1  0.000020           0.007780  0.992179  0.000021
# 2        Test_2  0.000009           0.000516  0.000002  0.999472
# 3        Test_3  0.998862           0.000018  0.001040  0.000080
# 4        Test_4  0.000001           0.001241  0.998752  0.000006
# ...         ...       ...                ...       ...       ...
# 1816  Test_1816  0.000001           0.001682  0.998314  0.000002
# 1817  Test_1817  0.000028           0.002584  0.000013  0.997376
# 1818  Test_1818  0.000007           0.001495  0.998495  0.000003
# 1819  Test_1819  0.997241           0.000368  0.001976  0.000415
# 1820  Test_1820  0.000236           0.014469  0.000067  0.985229
#
# [1821 rows x 5 columns]>

# %%
sub.to_csv('submission.csv', index=False)
