# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import pandas as pd
import numpy as np
from itertools import cycle
from fastai.vision import *
from fastai.metrics import *

torch.manual_seed(121)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(121)

# %%
train_csv = Path('/home/amey/LTTS/data/train-u1.csv')
valid_csv = Path('/home/amey/LTTS/data/valid.csv')

ALL_LBLS = ['No Finding',
            'Cardiomegaly',
            'Edema',
            'Consolidation',
            'Atelectasis',
            'Pleural Effusion',
            'Enlarged Cardiomediastinum',
            'Lung Opacity',
            'Lung Lesion',
            'Pneumonia',
            'Pneumothorax',
            'Pleural Other',
            'Fracture',
            'Support Devices']

EVAL_LBLS = ['Cardiomegaly',
             'Edema',
             'Consolidation',
             'Atelectasis',
             'Pleural Effusion',]

BS = 32
IMG_SZ = 224
IMG_MEAN = torch.FloatTensor([0.5027, 0.5027, 0.5027])
IMG_STD = torch.FloatTensor([0.2915, 0.2915, 0.2915])
GPU_IDS = [4,6]
torch.cuda.set_device(4)

EXP = 'fastai-resnext-224-u1'
RES_DIR = 'results/'+EXP+'/'
os.makedirs('results/', exist_ok=True)
os.makedirs(RES_DIR, exist_ok=True)

# %%
data_tfms = get_transforms(do_flip=True, flip_vert=False, max_rotate=None, max_zoom=1, max_lighting=None,
                          max_warp=0, p_affine=0, p_lighting=0)

train = ImageDataBunch.from_csv('/home1/amey/CheXpert-v1.0-downsampled', csv_labels=train_csv, folder='', 
                               label_col=ALL_LBLS, delimiter=',', suffix='', valid_pct=0, ds_tfms=data_tfms,
                               bs=BS, size=IMG_SZ).normalize([IMG_MEAN, IMG_STD])

valid = ImageDataBunch.from_csv('/home1/amey/CheXpert-v1.0-downsampled', csv_labels=valid_csv, folder='', 
                               label_col=ALL_LBLS, delimiter=',', suffix='', valid_pct=1, ds_tfms=data_tfms,
                               bs=BS, size=IMG_SZ).normalize([IMG_MEAN, IMG_STD])

data = DataBunch.create(train_ds=train.train_ds, valid_ds=valid.valid_ds, bs=BS)

data
# Out:
# /home/amey/.conda/envs/venv/lib/python3.6/site-packages/fastai/data_block.py:454: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# DataBunch;
#
# Train: LabelList (223414 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: MultiCategoryList
# No Finding;Support Devices,Cardiomegaly;Edema;Consolidation;Atelectasis;Pleural Effusion;Lung Opacity;Fracture,Consolidation;Lung Opacity;Fracture,Consolidation;Lung Opacity;Fracture,Edema
# Path: /home1/amey/CheXpert-v1.0-downsampled;
#
# Valid: LabelList (234 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: MultiCategoryList
# Atelectasis;Lung Opacity;Support Devices,No Finding,Cardiomegaly;Enlarged Cardiomediastinum,Edema;Consolidation;Atelectasis;Pleural Effusion;Enlarged Cardiomediastinum;Lung Opacity,Lung Opacity;Support Devices
# Path: /home1/amey/CheXpert-v1.0-downsampled;
#
# Test: None

# %%
# print(data.train_ds)
# print(data.valid_ds)
doc(DataBunch.create)

# %%
from sklearn.metrics import roc_curve, auc

class AUC(Callback):

    def __init__(self, num_cl=14, pick='micro', plot_auc=False, plot_title=EXP+' - validation AUC', plot_path=RES_DIR+'valid_ROC_AUC.png'):
        self.id_to_class = {
            0: 'No Finding',
            1: 'Cardiomegaly',
            2: 'Edema',
            3: 'Consolidation',
            4: 'Atelectasis',
            5: 'Pleural Effusion',
            6: 'Enlarged Cardiomediastinum',
            7: 'Lung Opacity',
            8: 'Lung Lesion',
            9: 'Pneumonia',
            10: 'Pneumothorax',
            11: 'Pleural Other',
            12: 'Fracture',
            13: 'Support Devices',
            'micro': 'micro',
            'macro': 'macro',
        }
        self.name = str(self.id_to_class[pick])+'-AUC'
        self.pick = pick
        self.num_cl = num_cl
        self.plot_path = plot_path
        self.plot_title = plot_title
        self.plot_auc = plot_auc
        
    
    def on_epoch_begin(self, **kwargs):
        self.outputs, self.targets = [], []
    
    def on_batch_end(self, last_output, last_target, **kwargs):
        self.outputs.append(last_output)
        self.targets.append(last_target)
    
    def on_epoch_end(self, last_metrics, **kwargs):
        self.outputs = torch.sigmoid(torch.cat(self.outputs)).cpu().detach().numpy()
        self.targets = torch.cat(self.targets).cpu().numpy()
        fpr, tpr, roc_auc = {}, {}, {}
        for i in range(self.num_cl):
          fpr[i], tpr[i], _ = roc_curve(self.targets[:, i], self.outputs[:, i])
          roc_auc[self.id_to_class[i]] = auc(fpr[i], tpr[i])
        
        # Compute micro-average ROC curve and ROC area
        self.targets, self.outputs = self.targets[:,1:6], self.outputs[:,1:6]
        fpr["micro"], tpr["micro"], _ = roc_curve(self.targets.ravel(), self.outputs.ravel())
        roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
        all_fpr = np.unique(np.concatenate([fpr[i] for i in range(1,6)]))

        # Then interpolate all ROC curves at this points
        mean_tpr = np.zeros_like(all_fpr)
        for i in range(1,6):
            mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

        # Finally average it and compute AUC
        mean_tpr /= 5

        fpr["macro"] = all_fpr
        tpr["macro"] = mean_tpr
        roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
        
        if self.plot_auc:
            # Plot all ROC curves
            plt.figure()
            plt.plot(fpr["micro"], tpr["micro"],
                     label='micro (auc- {0:0.2f})'.format(roc_auc["micro"]),
                     color='deeppink', linestyle=':', linewidth=2)

            plt.plot(fpr["macro"], tpr["macro"],
                     label='macro (auc- {0:0.2f})'.format(roc_auc["macro"]),
                     color='navy', linestyle=':', linewidth=2)

            colors = cycle(['blue', 'green', 'red', 'cyan', 'yellow', 'magenta', 'black'])
            for i, color in zip(range(12), colors):
                if roc_auc[self.id_to_class[i]] > 0:
                    plt.plot(fpr[i], tpr[i], color=color, lw=1,
                         label='{0} (auc- {1:0.2f})'.format(self.id_to_class[i], roc_auc[self.id_to_class[i]]))

            plt.plot([0, 1], [0, 1], 'k--', lw=2)
            plt.xlim([0.0, 1.0])
            plt.ylim([0.0, 1.05])
            plt.xlabel('False Positive Rate')
            plt.ylabel('True Positive Rate')
            plt.title('{}'.format(self.plot_title))
            plt.legend(loc="lower right")
            plt.savefig(self.plot_path)
            print('roc-auc curve saved to {}'.format(self.plot_path))
        
        return add_metrics(last_metrics, roc_auc[self.id_to_class[self.pick]])

acc_02 = partial(accuracy_thresh, thresh=0.4)

# %%
from resnext import resnext101_64x4d
model = resnext101_64x4d()
model.last_linear = nn.Linear(2048, 14)

learn = Learner(data, model, metrics=[acc_02, AUC(pick=1), AUC(pick=2), AUC(pick=3), AUC(pick=4), AUC(pick=5), AUC(pick='micro', plot_auc=True, plot_path=RES_DIR+'valid_ROC_AUC.png')])
learn.model = torch.nn.DataParallel(learn.model, device_ids=GPU_IDS)
learn
# Out:
# Learner(data=DataBunch;
#
# Train: LabelList (223414 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: MultiCategoryList
# No Finding;Support Devices,Cardiomegaly;Edema;Consolidation;Atelectasis;Pleural Effusion;Lung Opacity;Fracture,Consolidation;Lung Opacity;Fracture,Consolidation;Lung Opacity;Fracture,Edema
# Path: /home1/amey/CheXpert-v1.0-downsampled;
#
# Valid: LabelList (234 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: MultiCategoryList
# Atelectasis;Lung Opacity;Support Devices,No Finding,Cardiomegaly;Enlarged Cardiomediastinum,Edema;Consolidation;Atelectasis;Pleural Effusion;Enlarged Cardiomediastinum;Lung Opacity,Lung Opacity;Support Devices
# Path: /home1/amey/CheXpert-v1.0-downsampled;
#
# Test: None, model=DataParallel(
#   (module): ResNeXt101_64x4d(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=1, ceil_mode=False)
#       (4): Sequential(
#         (0): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (1): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (2): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#       )
#       (5): Sequential(
#         (0): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (1): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (2): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (3): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#       )
#       (6): Sequential(
#         (0): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (1): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (2): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (3): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (4): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (5): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (6): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (7): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (8): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (9): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (10): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (11): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (12): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (13): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (14): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (15): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (16): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (17): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (18): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (19): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (20): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (21): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (22): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#       )
#       (7): Sequential(
#         (0): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Sequential(
#               (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (1): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#         (2): Sequential(
#           (0): LambdaMap(
#             (0): Sequential(
#               (0): Sequential(
#                 (0): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): ReLU()
#                 (3): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#                 (4): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (5): ReLU()
#               )
#               (1): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): Lambda()
#           )
#           (1): LambdaReduce()
#           (2): ReLU()
#         )
#       )
#     )
#     (avg_pool): AvgPool2d(kernel_size=(7, 7), stride=(1, 1), padding=0)
#     (last_linear): Linear(in_features=2048, out_features=14, bias=True)
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of BCEWithLogitsLoss(), metrics=[functools.partial(<function accuracy_thresh at 0x7f22fec35510>, thresh=0.4), AUC
# num_cl: 14
# pick: 1
# plot_auc: False
# plot_title: fastai-resnext-224-u1 - validation AUC
# plot_path: results/fastai-resnext-224-u1/valid_ROC_AUC.png, AUC
# num_cl: 14
# pick: 2
# plot_auc: False
# plot_title: fastai-resnext-224-u1 - validation AUC
# plot_path: results/fastai-resnext-224-u1/valid_ROC_AUC.png, AUC
# num_cl: 14
# pick: 3
# plot_auc: False
# plot_title: fastai-resnext-224-u1 - validation AUC
# plot_path: results/fastai-resnext-224-u1/valid_ROC_AUC.png, AUC
# num_cl: 14
# pick: 4
# plot_auc: False
# plot_title: fastai-resnext-224-u1 - validation AUC
# plot_path: results/fastai-resnext-224-u1/valid_ROC_AUC.png, AUC
# num_cl: 14
# pick: 5
# plot_auc: False
# plot_title: fastai-resnext-224-u1 - validation AUC
# plot_path: results/fastai-resnext-224-u1/valid_ROC_AUC.png, AUC
# num_cl: 14
# pick: micro
# plot_auc: True
# plot_title: fastai-resnext-224-u1 - validation AUC
# plot_path: results/fastai-resnext-224-u1/valid_ROC_AUC.png], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=1, ceil_mode=False)
#   (4): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (9): ReLU()
#   (10): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (11): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): LambdaReduce()
#   (15): ReLU()
#   (16): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (17): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (18): ReLU()
#   (19): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (20): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (21): ReLU()
#   (22): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (23): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): Lambda()
#   (25): LambdaReduce()
#   (26): ReLU()
#   (27): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (28): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (29): ReLU()
#   (30): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (31): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (32): ReLU()
#   (33): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (34): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (35): Lambda()
#   (36): LambdaReduce()
#   (37): ReLU()
#   (38): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (39): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (40): ReLU()
#   (41): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#   (42): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (43): ReLU()
#   (44): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (45): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (46): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (47): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (48): LambdaReduce()
#   (49): ReLU()
#   (50): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (51): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (52): ReLU()
#   (53): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (54): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (55): ReLU()
#   (56): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (57): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (58): Lambda()
#   (59): LambdaReduce()
#   (60): ReLU()
#   (61): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (62): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (63): ReLU()
#   (64): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (65): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (66): ReLU()
#   (67): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (68): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (69): Lambda()
#   (70): LambdaReduce()
#   (71): ReLU()
#   (72): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (73): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (74): ReLU()
#   (75): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (76): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (77): ReLU()
#   (78): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (79): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (80): Lambda()
#   (81): LambdaReduce()
#   (82): ReLU()
#   (83): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (84): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (85): ReLU()
#   (86): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#   (87): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (88): ReLU()
#   (89): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (90): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (91): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (92): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (93): LambdaReduce()
#   (94): ReLU()
#   (95): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (96): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (97): ReLU()
#   (98): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (99): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (100): ReLU()
#   (101): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (102): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (103): Lambda()
#   (104): LambdaReduce()
#   (105): ReLU()
#   (106): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (107): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (108): ReLU()
#   (109): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (110): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (111): ReLU()
#   (112): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (113): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (114): Lambda()
#   (115): LambdaReduce()
#   (116): ReLU()
#   (117): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (118): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (119): ReLU()
#   (120): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (121): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (122): ReLU()
#   (123): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (124): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (125): Lambda()
#   (126): LambdaReduce()
#   (127): ReLU()
#   (128): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (129): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (130): ReLU()
#   (131): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (132): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (133): ReLU()
#   (134): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (135): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (136): Lambda()
#   (137): LambdaReduce()
#   (138): ReLU()
#   (139): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (140): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (141): ReLU()
#   (142): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (143): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (144): ReLU()
#   (145): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (146): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (147): Lambda()
#   (148): LambdaReduce()
#   (149): ReLU()
#   (150): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (151): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (152): ReLU()
#   (153): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (154): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (155): ReLU()
#   (156): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (157): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (158): Lambda()
#   (159): LambdaReduce()
#   (160): ReLU()
#   (161): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (162): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (163): ReLU()
#   (164): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (165): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (166): ReLU()
#   (167): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (168): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (169): Lambda()
#   (170): LambdaReduce()
#   (171): ReLU()
#   (172): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (173): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (174): ReLU()
#   (175): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (176): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (177): ReLU()
#   (178): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (179): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (180): Lambda()
#   (181): LambdaReduce()
#   (182): ReLU()
#   (183): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (184): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (185): ReLU()
#   (186): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (187): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (188): ReLU()
#   (189): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (190): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (191): Lambda()
#   (192): LambdaReduce()
#   (193): ReLU()
#   (194): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (195): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (196): ReLU()
#   (197): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (198): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (199): ReLU()
#   (200): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (201): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (202): Lambda()
#   (203): LambdaReduce()
#   (204): ReLU()
#   (205): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (206): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (207): ReLU()
#   (208): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (209): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (210): ReLU()
#   (211): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (212): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (213): Lambda()
#   (214): LambdaReduce()
#   (215): ReLU()
#   (216): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (217): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (218): ReLU()
#   (219): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (220): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (221): ReLU()
#   (222): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (223): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (224): Lambda()
#   (225): LambdaReduce()
#   (226): ReLU()
#   (227): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (228): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (229): ReLU()
#   (230): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (231): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (232): ReLU()
#   (233): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (234): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (235): Lambda()
#   (236): LambdaReduce()
#   (237): ReLU()
#   (238): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (239): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (240): ReLU()
#   (241): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (242): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (243): ReLU()
#   (244): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (245): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (246): Lambda()
#   (247): LambdaReduce()
#   (248): ReLU()
#   (249): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (250): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (251): ReLU()
#   (252): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (253): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (254): ReLU()
#   (255): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (256): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (257): Lambda()
#   (258): LambdaReduce()
#   (259): ReLU()
#   (260): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (261): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (262): ReLU()
#   (263): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (264): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (265): ReLU()
#   (266): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (267): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (268): Lambda()
#   (269): LambdaReduce()
#   (270): ReLU()
#   (271): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (272): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (273): ReLU()
#   (274): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (275): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (276): ReLU()
#   (277): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (278): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (279): Lambda()
#   (280): LambdaReduce()
#   (281): ReLU()
#   (282): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (283): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (284): ReLU()
#   (285): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (286): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (287): ReLU()
#   (288): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (289): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (290): Lambda()
#   (291): LambdaReduce()
#   (292): ReLU()
#   (293): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (294): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (295): ReLU()
#   (296): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (297): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (298): ReLU()
#   (299): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (300): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (301): Lambda()
#   (302): LambdaReduce()
#   (303): ReLU()
#   (304): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (305): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (306): ReLU()
#   (307): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (308): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (309): ReLU()
#   (310): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (311): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (312): Lambda()
#   (313): LambdaReduce()
#   (314): ReLU()
#   (315): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (316): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (317): ReLU()
#   (318): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (319): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (320): ReLU()
#   (321): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (322): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (323): Lambda()
#   (324): LambdaReduce()
#   (325): ReLU()
#   (326): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (327): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (328): ReLU()
#   (329): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (330): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (331): ReLU()
#   (332): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (333): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (334): Lambda()
#   (335): LambdaReduce()
#   (336): ReLU()
#   (337): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (338): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (339): ReLU()
#   (340): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#   (341): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (342): ReLU()
#   (343): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (344): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (345): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (346): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (347): LambdaReduce()
#   (348): ReLU()
#   (349): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (350): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (351): ReLU()
#   (352): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (353): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (354): ReLU()
#   (355): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (356): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (357): Lambda()
#   (358): LambdaReduce()
#   (359): ReLU()
#   (360): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (361): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (362): ReLU()
#   (363): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#   (364): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (365): ReLU()
#   (366): Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (367): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (368): Lambda()
#   (369): LambdaReduce()
#   (370): ReLU()
#   (371): AvgPool2d(kernel_size=(7, 7), stride=(1, 1), padding=0)
#   (372): Linear(in_features=2048, out_features=14, bias=True)
# )], add_time=True, silent=False)

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>Cardiomegaly-AUC</th>
#       <th>Edema-AUC</th>
#       <th>Consolidation-AUC</th>
#       <th>Atelectasis-AUC</th>
#       <th>Pleural Effusion-AUC</th>
#       <th>micro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='97' class='' max='6981', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.39% [97/6981 00:59<1:10:10 1.0773]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze()
learn.fit_one_cycle(2)
learn.recorder.plot_losses()
learn.save(EXP+'-stage-1')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>Cardiomegaly-AUC</th>
#       <th>Edema-AUC</th>
#       <th>Consolidation-AUC</th>
#       <th>Atelectasis-AUC</th>
#       <th>Pleural Effusion-AUC</th>
#       <th>micro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.372071</td>
#       <td>0.510908</td>
#       <td>0.815324</td>
#       <td>0.604359</td>
#       <td>0.881834</td>
#       <td>0.913765</td>
#       <td>0.746834</td>
#       <td>0.905443</td>
#       <td>0.701138</td>
#       <td>59:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.356507</td>
#       <td>0.352157</td>
#       <td>0.855617</td>
#       <td>0.821226</td>
#       <td>0.907937</td>
#       <td>0.889944</td>
#       <td>0.813068</td>
#       <td>0.921977</td>
#       <td>0.839365</td>
#       <td>58:16</td>
#     </tr>
#   </tbody>
# </table>
# /home/amey/.conda/envs/venv/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:808: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# roc-auc curve saved to results/fastai-resnext-224-u1/valid_ROC_AUC.png
# roc-auc curve saved to results/fastai-resnext-224-u1/valid_ROC_AUC.png

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>Cardiomegaly-AUC</th>
#       <th>Edema-AUC</th>
#       <th>Consolidation-AUC</th>
#       <th>Atelectasis-AUC</th>
#       <th>Pleural Effusion-AUC</th>
#       <th>micro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='91' class='' max='6981', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.30% [91/6981 00:47<1:00:05 1.1387]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(3*1e-4))
learn.save(EXP+'-stage-2')
learn.recorder.plot_losses()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>Cardiomegaly-AUC</th>
#       <th>Edema-AUC</th>
#       <th>Consolidation-AUC</th>
#       <th>Atelectasis-AUC</th>
#       <th>Pleural Effusion-AUC</th>
#       <th>micro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.345881</td>
#       <td>0.361043</td>
#       <td>0.857143</td>
#       <td>0.806166</td>
#       <td>0.908407</td>
#       <td>0.883160</td>
#       <td>0.813068</td>
#       <td>0.927518</td>
#       <td>0.835644</td>
#       <td>58:55</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.348137</td>
#       <td>0.349961</td>
#       <td>0.860806</td>
#       <td>0.814050</td>
#       <td>0.912992</td>
#       <td>0.882858</td>
#       <td>0.821266</td>
#       <td>0.924569</td>
#       <td>0.842213</td>
#       <td>58:01</td>
#     </tr>
#   </tbody>
# </table>
# roc-auc curve saved to results/fastai-resnext-224-u1/valid_ROC_AUC.png
# roc-auc curve saved to results/fastai-resnext-224-u1/valid_ROC_AUC.png

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>Cardiomegaly-AUC</th>
#       <th>Edema-AUC</th>
#       <th>Consolidation-AUC</th>
#       <th>Atelectasis-AUC</th>
#       <th>Pleural Effusion-AUC</th>
#       <th>micro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='91' class='' max='6981', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.30% [91/6981 00:44<55:55 1.3149]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
BS = 16
IMG_SZ = 320
IMG_MEAN = torch.FloatTensor([0.5027, 0.5027, 0.5027])
IMG_STD = torch.FloatTensor([0.2915, 0.2915, 0.2915])
GPU_IDS = [4, 6]
torch.cuda.set_device(4)

EXP = 'fastai-resnext-320-u1'
RES_DIR = 'results/'+EXP+'/'
os.makedirs('results/', exist_ok=True)
os.makedirs(RES_DIR, exist_ok=True)

data_tfms = get_transforms(do_flip=True, flip_vert=False, max_rotate=None, max_zoom=1, max_lighting=None,
                          max_warp=0, p_affine=0, p_lighting=0)

train = ImageDataBunch.from_csv('/home1/amey/CheXpert-v1.0-downsampled', csv_labels=train_csv, folder='', 
                               label_col=ALL_LBLS, delimiter=',', suffix='', valid_pct=0, ds_tfms=data_tfms,
                               bs=BS, size=IMG_SZ).normalize([IMG_MEAN, IMG_STD])

valid = ImageDataBunch.from_csv('/home1/amey/CheXpert-v1.0-downsampled', csv_labels=valid_csv, folder='', 
                               label_col=ALL_LBLS, delimiter=',', suffix='', valid_pct=1, ds_tfms=data_tfms,
                               bs=BS, size=IMG_SZ).normalize([IMG_MEAN, IMG_STD])

data = DataBunch.create(train_ds=train.train_ds, valid_ds=valid.valid_ds, bs=BS)

data
# Out:
# /home/amey/.conda/envs/venv/lib/python3.6/site-packages/fastai/data_block.py:454: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# DataBunch;
#
# Train: LabelList (223414 items)
# x: ImageList
# Image (3, 320, 320),Image (3, 320, 320),Image (3, 320, 320),Image (3, 320, 320),Image (3, 320, 320)
# y: MultiCategoryList
# No Finding;Support Devices,Cardiomegaly;Edema;Consolidation;Atelectasis;Pleural Effusion;Lung Opacity;Fracture,Consolidation;Lung Opacity;Fracture,Consolidation;Lung Opacity;Fracture,Edema
# Path: /home1/amey/CheXpert-v1.0-downsampled;
#
# Valid: LabelList (234 items)
# x: ImageList
# Image (3, 320, 320),Image (3, 320, 320),Image (3, 320, 320),Image (3, 320, 320),Image (3, 320, 320)
# y: MultiCategoryList
# Atelectasis;Lung Opacity;Support Devices,No Finding,Cardiomegaly;Enlarged Cardiomediastinum,Edema;Consolidation;Atelectasis;Pleural Effusion;Enlarged Cardiomediastinum;Lung Opacity,Lung Opacity;Support Devices
# Path: /home1/amey/CheXpert-v1.0-downsampled;
#
# Test: None

# %%
from resnext import resnext101_64x4d
model = resnext101_64x4d()
model.last_linear = nn.Linear(2048, 14)

learn = Learner(data, model, metrics=[acc_02, AUC(pick=1), AUC(pick=2), AUC(pick=3), AUC(pick=4), AUC(pick=5), AUC(pick='micro', plot_auc=True, plot_path=RES_DIR+'valid_ROC_AUC.png')])
# learn.model = torch.nn.DataParallel(learn.model, device_ids=GPU_IDS)
learn.load('fastai-resnext-224-u1-stage-2')
model.last_linear = nn.Sequential(nn.Linear(32768, 2048), 
                                  nn.ReLU(True),
                                  nn.Dropout(),
                                  nn.Linear(2048, 14))
learn = Learner(data, learn.model, metrics=[acc_02, AUC(pick=1), AUC(pick=2), AUC(pick=3), AUC(pick=4), AUC(pick=5), AUC(pick='micro', plot_auc=True, plot_path=RES_DIR+'valid_ROC_AUC.png')])
learn.model = torch.nn.DataParallel(learn.model, device_ids=GPU_IDS)

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>Cardiomegaly-AUC</th>
#       <th>Edema-AUC</th>
#       <th>Consolidation-AUC</th>
#       <th>Atelectasis-AUC</th>
#       <th>Pleural Effusion-AUC</th>
#       <th>micro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='13963', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.59% [83/13963 00:48<2:15:53 1.5563]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-4))
learn.save(EXP+'-stage-1')
learn.recorder.plot_losses()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>Cardiomegaly-AUC</th>
#       <th>Edema-AUC</th>
#       <th>Consolidation-AUC</th>
#       <th>Atelectasis-AUC</th>
#       <th>Pleural Effusion-AUC</th>
#       <th>micro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.356542</td>
#       <td>0.347392</td>
#       <td>0.862637</td>
#       <td>0.777286</td>
#       <td>0.924162</td>
#       <td>0.898839</td>
#       <td>0.815990</td>
#       <td>0.938243</td>
#       <td>0.836699</td>
#       <td>2:14:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.350008</td>
#       <td>0.340887</td>
#       <td>0.865690</td>
#       <td>0.814050</td>
#       <td>0.925338</td>
#       <td>0.882105</td>
#       <td>0.827597</td>
#       <td>0.936545</td>
#       <td>0.852651</td>
#       <td>2:12:55</td>
#     </tr>
#   </tbody>
# </table>
# roc-auc curve saved to results/fastai-resnext-320-u1/valid_ROC_AUC.png

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>Cardiomegaly-AUC</th>
#       <th>Edema-AUC</th>
#       <th>Consolidation-AUC</th>
#       <th>Atelectasis-AUC</th>
#       <th>Pleural Effusion-AUC</th>
#       <th>micro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='82' class='' max='13963', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.59% [82/13963 00:48<2:18:12 0.7735]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(5*1e-5))
learn.save(EXP+'-stage-2')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>Cardiomegaly-AUC</th>
#       <th>Edema-AUC</th>
#       <th>Consolidation-AUC</th>
#       <th>Atelectasis-AUC</th>
#       <th>Pleural Effusion-AUC</th>
#       <th>micro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.341051</td>
#       <td>0.344374</td>
#       <td>0.865079</td>
#       <td>0.803242</td>
#       <td>0.921105</td>
#       <td>0.886929</td>
#       <td>0.825162</td>
#       <td>0.939405</td>
#       <td>0.853398</td>
#       <td>2:14:42</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.342044</td>
#       <td>0.345605</td>
#       <td>0.863248</td>
#       <td>0.804748</td>
#       <td>0.922751</td>
#       <td>0.883914</td>
#       <td>0.826542</td>
#       <td>0.937528</td>
#       <td>0.849125</td>
#       <td>2:12:25</td>
#     </tr>
#   </tbody>
# </table>
# roc-auc curve saved to results/fastai-resnext-320-u1/valid_ROC_AUC.png
# roc-auc curve saved to results/fastai-resnext-320-u1/valid_ROC_AUC.png

# %%
from resnext import resnext101_64x4d
model = resnext101_64x4d()
model.last_linear = nn.Sequential(nn.Linear(32768, 2048), 
                                  nn.ReLU(True),
                                  nn.Dropout(),
                                  nn.Linear(2048, 14))

learn = Learner(data, model, metrics=[acc_02, AUC(pick=1), AUC(pick=2), AUC(pick=3), AUC(pick=4), AUC(pick=5), AUC(pick='micro', plot_auc=True, plot_path=RES_DIR+'valid_ROC_AUC.png')])

learn.model = torch.nn.DataParallel(learn.model, device_ids=GPU_IDS)
learn.load('fastai-resnext-320-u1-stage-1')

learn.validate(data.valid_dl)
# Out:
# roc-auc curve saved to results/fastai-resnext-320-u1/valid_ROC_AUC.png
# [0.34088695,
#  tensor(0.8657),
#  0.8140503189227498,
#  0.9253380364491476,
#  0.8821046283732851,
#  0.8275974025974027,
#  0.9365448208061489,
#  0.8526507913652266]

# %%
from resnext import resnext101_64x4d
model = resnext101_64x4d()
model.last_linear = nn.Sequential(nn.Linear(32768, 2048), 
                                  nn.ReLU(True),
                                  nn.Dropout(),
                                  nn.Linear(2048, 14))

learn = Learner(data, model, metrics=[acc_02, AUC(pick=1), AUC(pick=2), AUC(pick=3), AUC(pick=4), AUC(pick=5), AUC(pick='micro', plot_auc=True, plot_path=RES_DIR+'valid_ROC_AUC.png')])

learn.model = torch.nn.DataParallel(learn.model, device_ids=GPU_IDS)
learn.load('fastai-resnext-320-u1-stage-2')

learn.validate(data.valid_dl)
# Out:
# roc-auc curve saved to results/fastai-resnext-320-u1/valid_ROC_AUC.png
# [0.34560496,
#  tensor(0.8632),
#  0.8047484053862509,
#  0.9227513227513228,
#  0.8839137645107795,
#  0.8265422077922078,
#  0.9375279292161944,
#  0.8491249644887746]
