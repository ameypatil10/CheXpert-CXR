# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import pandas as pd
import numpy as np
from itertools import cycle
from fastai.vision import *
from fastai.metrics import *
from efficientnet_pytorch import EfficientNet

torch.manual_seed(121)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(121)

# %%
train_csv = Path('/home/amey/LTTS/data/train-u1.csv')
valid_csv = Path('/home/amey/LTTS/data/valid.csv')

ALL_LBLS = ['No Finding',
            'Cardiomegaly',
            'Edema',
            'Consolidation',
            'Atelectasis',
            'Pleural Effusion',
            'Enlarged Cardiomediastinum',
            'Lung Opacity',
            'Lung Lesion',
            'Pneumonia',
            'Pneumothorax',
            'Pleural Other',
            'Fracture',
            'Support Devices']

EVAL_LBLS = ['Cardiomegaly',
             'Edema',
             'Consolidation',
             'Atelectasis',
             'Pleural Effusion',]

BS = 32
IMG_SZ = 320
IMG_MEAN = torch.FloatTensor([0.5027, 0.5027, 0.5027])
IMG_STD = torch.FloatTensor([0.2915, 0.2915, 0.2915])
GPU_IDS = [6,7]
torch.cuda.set_device(GPU_IDS[0])

EXP = 'fastai-effnetB3-320-u1'
RES_DIR = 'results/'+EXP+'/'
os.makedirs('results/', exist_ok=True)
os.makedirs(RES_DIR, exist_ok=True)

# %%
data_tfms = get_transforms(do_flip=True, flip_vert=False, max_rotate=None, max_zoom=1, max_lighting=None,
                          max_warp=0, p_affine=0, p_lighting=0)

train = ImageDataBunch.from_csv('/home1/amey/CheXpert-v1.0-downsampled', csv_labels=train_csv, folder='', 
                               label_col=ALL_LBLS, delimiter=',', suffix='', valid_pct=0, ds_tfms=data_tfms,
                               bs=BS, size=IMG_SZ).normalize([IMG_MEAN, IMG_STD])

valid = ImageDataBunch.from_csv('/home1/amey/CheXpert-v1.0-downsampled', csv_labels=valid_csv, folder='', 
                               label_col=ALL_LBLS, delimiter=',', suffix='', valid_pct=1, ds_tfms=data_tfms,
                               bs=BS, size=IMG_SZ).normalize([IMG_MEAN, IMG_STD])

data = DataBunch.create(train_ds=train.train_ds, valid_ds=valid.valid_ds, bs=BS)

data
# Out:
# /home/amey/.conda/envs/venv/lib/python3.6/site-packages/fastai/data_block.py:454: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# DataBunch;
#
# Train: LabelList (223414 items)
# x: ImageList
# Image (3, 320, 320),Image (3, 320, 320),Image (3, 320, 320),Image (3, 320, 320),Image (3, 320, 320)
# y: MultiCategoryList
# No Finding;Support Devices,Cardiomegaly;Edema;Consolidation;Atelectasis;Pleural Effusion;Lung Opacity;Fracture,Consolidation;Lung Opacity;Fracture,Consolidation;Lung Opacity;Fracture,Edema
# Path: /home1/amey/CheXpert-v1.0-downsampled;
#
# Valid: LabelList (234 items)
# x: ImageList
# Image (3, 320, 320),Image (3, 320, 320),Image (3, 320, 320),Image (3, 320, 320),Image (3, 320, 320)
# y: MultiCategoryList
# Atelectasis;Lung Opacity;Support Devices,No Finding,Cardiomegaly;Enlarged Cardiomediastinum,Edema;Consolidation;Atelectasis;Pleural Effusion;Enlarged Cardiomediastinum;Lung Opacity,Lung Opacity;Support Devices
# Path: /home1/amey/CheXpert-v1.0-downsampled;
#
# Test: None

# %%
# print(data.train_ds)
# print(data.valid_ds)
# doc(DataBunch.create)

# %%
from sklearn.metrics import roc_curve, auc

class AUC(Callback):

    def __init__(self, num_cl=14, pick='micro', plot_auc=False, plot_title=EXP+' - validation AUC', plot_path=RES_DIR+'valid_ROC_AUC.png'):
        self.id_to_class = {
            0: 'No Finding',
            1: 'Cardiomegaly',
            2: 'Edema',
            3: 'Consolidation',
            4: 'Atelectasis',
            5: 'Pleural Effusion',
            6: 'Enlarged Cardiomediastinum',
            7: 'Lung Opacity',
            8: 'Lung Lesion',
            9: 'Pneumonia',
            10: 'Pneumothorax',
            11: 'Pleural Other',
            12: 'Fracture',
            13: 'Support Devices',
            'micro': 'micro',
            'macro': 'macro',
        }
        self.name = str(self.id_to_class[pick])+'-AUC'
        self.pick = pick
        self.num_cl = num_cl
        self.plot_path = plot_path
        self.plot_title = plot_title
        self.plot_auc = plot_auc
        
    
    def on_epoch_begin(self, **kwargs):
        self.outputs, self.targets = [], []
    
    def on_batch_end(self, last_output, last_target, **kwargs):
        self.outputs.append(last_output)
        self.targets.append(last_target)
    
    def on_epoch_end(self, last_metrics, **kwargs):
        self.outputs = torch.sigmoid(torch.cat(self.outputs)).cpu().detach().numpy()
        self.targets = torch.cat(self.targets).cpu().numpy()
        fpr, tpr, roc_auc = {}, {}, {}
        for i in range(self.num_cl):
          fpr[i], tpr[i], _ = roc_curve(self.targets[:, i], self.outputs[:, i])
          roc_auc[self.id_to_class[i]] = auc(fpr[i], tpr[i])
        
        # Compute micro-average ROC curve and ROC area
        self.targets, self.outputs = self.targets[:,1:6], self.outputs[:,1:6]
        fpr["micro"], tpr["micro"], _ = roc_curve(self.targets.ravel(), self.outputs.ravel())
        roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
        all_fpr = np.unique(np.concatenate([fpr[i] for i in range(1,6)]))

        # Then interpolate all ROC curves at this points
        mean_tpr = np.zeros_like(all_fpr)
        for i in range(1,6):
            mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

        # Finally average it and compute AUC
        mean_tpr /= 5

        fpr["macro"] = all_fpr
        tpr["macro"] = mean_tpr
        roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
        
        if self.plot_auc:
            # Plot all ROC curves
            plt.figure()
            plt.plot(fpr["micro"], tpr["micro"],
                     label='micro (auc- {0:0.2f})'.format(roc_auc["micro"]),
                     color='deeppink', linestyle=':', linewidth=2)

            plt.plot(fpr["macro"], tpr["macro"],
                     label='macro (auc- {0:0.2f})'.format(roc_auc["macro"]),
                     color='navy', linestyle=':', linewidth=2)

            colors = cycle(['blue', 'green', 'red', 'cyan', 'yellow', 'magenta', 'black'])
            for i, color in zip(range(12), colors):
                if roc_auc[self.id_to_class[i]] > 0:
                    plt.plot(fpr[i], tpr[i], color=color, lw=1,
                         label='{0} (auc- {1:0.2f})'.format(self.id_to_class[i], roc_auc[self.id_to_class[i]]))

            plt.plot([0, 1], [0, 1], 'k--', lw=2)
            plt.xlim([0.0, 1.0])
            plt.ylim([0.0, 1.05])
            plt.xlabel('False Positive Rate')
            plt.ylabel('True Positive Rate')
            plt.title('{}'.format(self.plot_title))
            plt.legend(loc="lower right")
            plt.savefig(self.plot_path)
            print('roc-auc curve saved to {}'.format(self.plot_path))
        
        return add_metrics(last_metrics, roc_auc[self.id_to_class[self.pick]])

acc_02 = partial(accuracy_thresh, thresh=0.4)

# %%
model_name = 'efficientnet-b3'
def getModel():
    model = EfficientNet.from_pretrained(model_name)
#     model._bn1 = nn.Identity()
    model._fc = nn.Linear(1536,data.c)
    return model

# %%
learn = Learner(data, getModel(), metrics=[acc_02, AUC(pick=1), AUC(pick=2), AUC(pick=3), AUC(pick=4), AUC(pick=5), AUC(pick='micro', plot_auc=True, plot_path=RES_DIR+'valid_ROC_AUC.png')])
learn.model = torch.nn.DataParallel(learn.model, device_ids=GPU_IDS)
# Out:
# Loaded pretrained weights for efficientnet-b3

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>Cardiomegaly-AUC</th>
#       <th>Edema-AUC</th>
#       <th>Consolidation-AUC</th>
#       <th>Atelectasis-AUC</th>
#       <th>Pleural Effusion-AUC</th>
#       <th>micro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='92' class='' max='6981', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.32% [92/6981 00:43<54:40 2.1743]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze()
learn.fit_one_cycle(2)
learn.recorder.plot_losses()
learn.save(EXP+'-stage-1')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>Cardiomegaly-AUC</th>
#       <th>Edema-AUC</th>
#       <th>Consolidation-AUC</th>
#       <th>Atelectasis-AUC</th>
#       <th>Pleural Effusion-AUC</th>
#       <th>micro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.355727</td>
#       <td>0.385209</td>
#       <td>0.845238</td>
#       <td>0.762934</td>
#       <td>0.889242</td>
#       <td>0.890849</td>
#       <td>0.861851</td>
#       <td>0.915631</td>
#       <td>0.818198</td>
#       <td>47:35</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.337190</td>
#       <td>0.342759</td>
#       <td>0.858669</td>
#       <td>0.795004</td>
#       <td>0.921928</td>
#       <td>0.865069</td>
#       <td>0.818588</td>
#       <td>0.925731</td>
#       <td>0.842089</td>
#       <td>32:40</td>
#     </tr>
#   </tbody>
# </table>
# roc-auc curve saved to results/fastai-effnetB3-320-u1/valid_ROC_AUC.png
# /home/amey/.conda/envs/venv/lib/python3.6/site-packages/sklearn/metrics/_ranking.py:808: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# roc-auc curve saved to results/fastai-effnetB3-320-u1/valid_ROC_AUC.png

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>Cardiomegaly-AUC</th>
#       <th>Edema-AUC</th>
#       <th>Consolidation-AUC</th>
#       <th>Atelectasis-AUC</th>
#       <th>Pleural Effusion-AUC</th>
#       <th>micro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='6981', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.19% [83/6981 00:25<35:26 1.0305]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(3*1e-5))
learn.recorder.plot_losses()
learn.save(EXP+'-stage-2')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>Cardiomegaly-AUC</th>
#       <th>Edema-AUC</th>
#       <th>Consolidation-AUC</th>
#       <th>Atelectasis-AUC</th>
#       <th>Pleural Effusion-AUC</th>
#       <th>micro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.338281</td>
#       <td>0.344783</td>
#       <td>0.856532</td>
#       <td>0.790131</td>
#       <td>0.922163</td>
#       <td>0.853309</td>
#       <td>0.814286</td>
#       <td>0.925463</td>
#       <td>0.838598</td>
#       <td>32:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.330613</td>
#       <td>0.343659</td>
#       <td>0.858059</td>
#       <td>0.791017</td>
#       <td>0.921928</td>
#       <td>0.860395</td>
#       <td>0.820617</td>
#       <td>0.925552</td>
#       <td>0.841330</td>
#       <td>31:57</td>
#     </tr>
#   </tbody>
# </table>
# roc-auc curve saved to results/fastai-effnetB3-320-u1/valid_ROC_AUC.png
# roc-auc curve saved to results/fastai-effnetB3-320-u1/valid_ROC_AUC.png

# %%
BS = 8
IMG_SZ = 768
IMG_MEAN = torch.FloatTensor([0.5027, 0.5027, 0.5027])
IMG_STD = torch.FloatTensor([0.2915, 0.2915, 0.2915])

EXP = 'fastai-effnetB3-768-u1'
RES_DIR = 'results/'+EXP+'/'
os.makedirs('results/', exist_ok=True)
os.makedirs(RES_DIR, exist_ok=True)

data_tfms = get_transforms(do_flip=True, flip_vert=False, max_rotate=None, max_zoom=1, max_lighting=None,
                          max_warp=0, p_affine=0, p_lighting=0)

train = ImageDataBunch.from_csv('/home1/himanshu', csv_labels=train_csv, folder='', 
                               label_col=ALL_LBLS, delimiter=',', suffix='', valid_pct=0, ds_tfms=data_tfms,
                               bs=BS, size=IMG_SZ).normalize([IMG_MEAN, IMG_STD])

valid = ImageDataBunch.from_csv('/home1/himanshu', csv_labels=valid_csv, folder='', 
                               label_col=ALL_LBLS, delimiter=',', suffix='', valid_pct=1, ds_tfms=data_tfms,
                               bs=BS, size=IMG_SZ).normalize([IMG_MEAN, IMG_STD])

data = DataBunch.create(train_ds=train.train_ds, valid_ds=valid.valid_ds, bs=BS)

data
# Out:
# /home/amey/.conda/envs/venv/lib/python3.6/site-packages/fastai/data_block.py:454: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# DataBunch;
#
# Train: LabelList (223414 items)
# x: ImageList
# Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768)
# y: MultiCategoryList
# No Finding;Support Devices,Cardiomegaly;Edema;Consolidation;Atelectasis;Pleural Effusion;Lung Opacity;Fracture,Consolidation;Lung Opacity;Fracture,Consolidation;Lung Opacity;Fracture,Edema
# Path: /home1/himanshu;
#
# Valid: LabelList (234 items)
# x: ImageList
# Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768)
# y: MultiCategoryList
# Atelectasis;Lung Opacity;Support Devices,No Finding,Cardiomegaly;Enlarged Cardiomediastinum,Edema;Consolidation;Atelectasis;Pleural Effusion;Enlarged Cardiomediastinum;Lung Opacity,Lung Opacity;Support Devices
# Path: /home1/himanshu;
#
# Test: None

# %%
learn = Learner(data, getModel(), metrics=[acc_02, AUC(pick=1), AUC(pick=2), AUC(pick=3), AUC(pick=4), AUC(pick=5), AUC(pick='micro', plot_auc=True, plot_path=RES_DIR+'valid_ROC_AUC.png')])
learn.model = torch.nn.DataParallel(learn.model, device_ids=GPU_IDS)
learn.load('fastai-effnetB3-320-u1-stage-2')
# Out:
# Loaded pretrained weights for efficientnet-b3
# Learner(data=DataBunch;
#
# Train: LabelList (223414 items)
# x: ImageList
# Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768)
# y: MultiCategoryList
# No Finding;Support Devices,Cardiomegaly;Edema;Consolidation;Atelectasis;Pleural Effusion;Lung Opacity;Fracture,Consolidation;Lung Opacity;Fracture,Consolidation;Lung Opacity;Fracture,Edema
# Path: /home1/himanshu;
#
# Valid: LabelList (234 items)
# x: ImageList
# Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768),Image (3, 768, 768)
# y: MultiCategoryList
# Atelectasis;Lung Opacity;Support Devices,No Finding,Cardiomegaly;Enlarged Cardiomediastinum,Edema;Consolidation;Atelectasis;Pleural Effusion;Enlarged Cardiomediastinum;Lung Opacity,Lung Opacity;Support Devices
# Path: /home1/himanshu;
#
# Test: None, model=DataParallel(
#   (module): EfficientNet(
#     (_conv_stem): Conv2dStaticSamePadding(
#       3, 40, kernel_size=(3, 3), stride=(2, 2), bias=False
#       (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#     )
#     (_bn0): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_blocks): ModuleList(
#       (0): MBConvBlock(
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           40, 40, kernel_size=(3, 3), stride=[1, 1], groups=40, bias=False
#           (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#         )
#         (_bn1): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           40, 10, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           10, 40, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           40, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (1): MBConvBlock(
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           24, 24, kernel_size=(3, 3), stride=(1, 1), groups=24, bias=False
#           (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#         )
#         (_bn1): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           24, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 24, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (2): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           144, 144, kernel_size=(3, 3), stride=[2, 2], groups=144, bias=False
#           (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#         )
#         (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           144, 6, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           6, 144, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (3): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False
#           (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#         )
#         (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           192, 8, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           8, 192, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (4): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False
#           (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#         )
#         (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           192, 8, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           8, 192, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (5): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           192, 192, kernel_size=(5, 5), stride=[2, 2], groups=192, bias=False
#           (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#         )
#         (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           192, 8, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           8, 192, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (6): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           288, 288, kernel_size=(5, 5), stride=(1, 1), groups=288, bias=False
#           (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#         )
#         (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           288, 12, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           12, 288, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (7): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           288, 288, kernel_size=(5, 5), stride=(1, 1), groups=288, bias=False
#           (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#         )
#         (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           288, 12, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           12, 288, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (8): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           288, 288, kernel_size=(3, 3), stride=[2, 2], groups=288, bias=False
#           (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#         )
#         (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           288, 12, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           12, 288, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (9): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           576, 576, kernel_size=(3, 3), stride=(1, 1), groups=576, bias=False
#           (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#         )
#         (_bn1): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           576, 24, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           24, 576, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (10): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           576, 576, kernel_size=(3, 3), stride=(1, 1), groups=576, bias=False
#           (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#         )
#         (_bn1): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           576, 24, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           24, 576, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (11): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           576, 576, kernel_size=(3, 3), stride=(1, 1), groups=576, bias=False
#           (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#         )
#         (_bn1): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           576, 24, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           24, 576, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (12): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           576, 576, kernel_size=(3, 3), stride=(1, 1), groups=576, bias=False
#           (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#         )
#         (_bn1): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           576, 24, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           24, 576, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (13): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           576, 576, kernel_size=(5, 5), stride=[1, 1], groups=576, bias=False
#           (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#         )
#         (_bn1): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           576, 24, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           24, 576, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           576, 136, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(136, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (14): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           816, 816, kernel_size=(5, 5), stride=(1, 1), groups=816, bias=False
#           (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#         )
#         (_bn1): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           816, 34, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           34, 816, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(136, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (15): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           816, 816, kernel_size=(5, 5), stride=(1, 1), groups=816, bias=False
#           (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#         )
#         (_bn1): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           816, 34, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           34, 816, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(136, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (16): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           816, 816, kernel_size=(5, 5), stride=(1, 1), groups=816, bias=False
#           (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#         )
#         (_bn1): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           816, 34, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           34, 816, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(136, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (17): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           816, 816, kernel_size=(5, 5), stride=(1, 1), groups=816, bias=False
#           (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#         )
#         (_bn1): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           816, 34, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           34, 816, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(136, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (18): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           816, 816, kernel_size=(5, 5), stride=[2, 2], groups=816, bias=False
#           (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#         )
#         (_bn1): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           816, 34, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           34, 816, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           816, 232, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(232, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (19): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1392, 1392, kernel_size=(5, 5), stride=(1, 1), groups=1392, bias=False
#           (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#         )
#         (_bn1): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1392, 58, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           58, 1392, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(232, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (20): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1392, 1392, kernel_size=(5, 5), stride=(1, 1), groups=1392, bias=False
#           (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#         )
#         (_bn1): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1392, 58, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           58, 1392, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(232, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (21): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1392, 1392, kernel_size=(5, 5), stride=(1, 1), groups=1392, bias=False
#           (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#         )
#         (_bn1): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1392, 58, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           58, 1392, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(232, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (22): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1392, 1392, kernel_size=(5, 5), stride=(1, 1), groups=1392, bias=False
#           (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#         )
#         (_bn1): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1392, 58, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           58, 1392, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(232, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (23): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1392, 1392, kernel_size=(5, 5), stride=(1, 1), groups=1392, bias=False
#           (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#         )
#         (_bn1): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1392, 58, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           58, 1392, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(232, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (24): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           1392, 1392, kernel_size=(3, 3), stride=[1, 1], groups=1392, bias=False
#           (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#         )
#         (_bn1): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           1392, 58, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           58, 1392, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           1392, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#       (25): MBConvBlock(
#         (_expand_conv): Conv2dStaticSamePadding(
#           384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_depthwise_conv): Conv2dStaticSamePadding(
#           2304, 2304, kernel_size=(3, 3), stride=(1, 1), groups=2304, bias=False
#           (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#         )
#         (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_se_reduce): Conv2dStaticSamePadding(
#           2304, 96, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_se_expand): Conv2dStaticSamePadding(
#           96, 2304, kernel_size=(1, 1), stride=(1, 1)
#           (static_padding): Identity()
#         )
#         (_project_conv): Conv2dStaticSamePadding(
#           2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (static_padding): Identity()
#         )
#         (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#         (_swish): MemoryEfficientSwish()
#       )
#     )
#     (_conv_head): Conv2dStaticSamePadding(
#       384, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False
#       (static_padding): Identity()
#     )
#     (_bn1): BatchNorm2d(1536, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#     (_dropout): Dropout(p=0.3, inplace=False)
#     (_fc): Linear(in_features=1536, out_features=14, bias=True)
#     (_swish): MemoryEfficientSwish()
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of BCEWithLogitsLoss(), metrics=[functools.partial(<function accuracy_thresh at 0x7f064975e488>, thresh=0.4), AUC
# num_cl: 14
# pick: 1
# plot_auc: False
# plot_title: fastai-effnetB3-320-u1 - validation AUC
# plot_path: results/fastai-effnetB3-320-u1/valid_ROC_AUC.png, AUC
# num_cl: 14
# pick: 2
# plot_auc: False
# plot_title: fastai-effnetB3-320-u1 - validation AUC
# plot_path: results/fastai-effnetB3-320-u1/valid_ROC_AUC.png, AUC
# num_cl: 14
# pick: 3
# plot_auc: False
# plot_title: fastai-effnetB3-320-u1 - validation AUC
# plot_path: results/fastai-effnetB3-320-u1/valid_ROC_AUC.png, AUC
# num_cl: 14
# pick: 4
# plot_auc: False
# plot_title: fastai-effnetB3-320-u1 - validation AUC
# plot_path: results/fastai-effnetB3-320-u1/valid_ROC_AUC.png, AUC
# num_cl: 14
# pick: 5
# plot_auc: False
# plot_title: fastai-effnetB3-320-u1 - validation AUC
# plot_path: results/fastai-effnetB3-320-u1/valid_ROC_AUC.png, AUC
# num_cl: 14
# pick: micro
# plot_auc: True
# plot_title: fastai-effnetB3-320-u1 - validation AUC
# plot_path: results/fastai-effnetB3-768-u1/valid_ROC_AUC.png], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[], layer_groups=[Sequential(
#   (0): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   (1): ParameterModule()
#   (2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (3): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (4): ParameterModule()
#   (5): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (6): Identity()
#   (7): ParameterModule()
#   (8): ParameterModule()
#   (9): Identity()
#   (10): ParameterModule()
#   (11): ParameterModule()
#   (12): Identity()
#   (13): ParameterModule()
#   (14): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (15): MemoryEfficientSwish()
#   (16): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (17): ParameterModule()
#   (18): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (19): Identity()
#   (20): ParameterModule()
#   (21): ParameterModule()
#   (22): Identity()
#   (23): ParameterModule()
#   (24): ParameterModule()
#   (25): Identity()
#   (26): ParameterModule()
#   (27): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (28): MemoryEfficientSwish()
#   (29): Identity()
#   (30): ParameterModule()
#   (31): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (32): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   (33): ParameterModule()
#   (34): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (35): Identity()
#   (36): ParameterModule()
#   (37): ParameterModule()
#   (38): Identity()
#   (39): ParameterModule()
#   (40): ParameterModule()
#   (41): Identity()
#   (42): ParameterModule()
#   (43): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (44): MemoryEfficientSwish()
#   (45): Identity()
#   (46): ParameterModule()
#   (47): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (48): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (49): ParameterModule()
#   (50): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (51): Identity()
#   (52): ParameterModule()
#   (53): ParameterModule()
#   (54): Identity()
#   (55): ParameterModule()
#   (56): ParameterModule()
#   (57): Identity()
#   (58): ParameterModule()
#   (59): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (60): MemoryEfficientSwish()
#   (61): Identity()
#   (62): ParameterModule()
#   (63): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (64): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (65): ParameterModule()
#   (66): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (67): Identity()
#   (68): ParameterModule()
#   (69): ParameterModule()
#   (70): Identity()
#   (71): ParameterModule()
#   (72): ParameterModule()
#   (73): Identity()
#   (74): ParameterModule()
#   (75): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (76): MemoryEfficientSwish()
#   (77): Identity()
#   (78): ParameterModule()
#   (79): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (80): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (81): ParameterModule()
#   (82): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (83): Identity()
#   (84): ParameterModule()
#   (85): ParameterModule()
#   (86): Identity()
#   (87): ParameterModule()
#   (88): ParameterModule()
#   (89): Identity()
#   (90): ParameterModule()
#   (91): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (92): MemoryEfficientSwish()
#   (93): Identity()
#   (94): ParameterModule()
#   (95): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (96): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (97): ParameterModule()
#   (98): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (99): Identity()
#   (100): ParameterModule()
#   (101): ParameterModule()
#   (102): Identity()
#   (103): ParameterModule()
#   (104): ParameterModule()
#   (105): Identity()
#   (106): ParameterModule()
#   (107): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (108): MemoryEfficientSwish()
#   (109): Identity()
#   (110): ParameterModule()
#   (111): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (112): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (113): ParameterModule()
#   (114): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (115): Identity()
#   (116): ParameterModule()
#   (117): ParameterModule()
#   (118): Identity()
#   (119): ParameterModule()
#   (120): ParameterModule()
#   (121): Identity()
#   (122): ParameterModule()
#   (123): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (124): MemoryEfficientSwish()
#   (125): Identity()
#   (126): ParameterModule()
#   (127): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (128): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   (129): ParameterModule()
#   (130): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (131): Identity()
#   (132): ParameterModule()
#   (133): ParameterModule()
#   (134): Identity()
#   (135): ParameterModule()
#   (136): ParameterModule()
#   (137): Identity()
#   (138): ParameterModule()
#   (139): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (140): MemoryEfficientSwish()
#   (141): Identity()
#   (142): ParameterModule()
#   (143): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (144): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (145): ParameterModule()
#   (146): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (147): Identity()
#   (148): ParameterModule()
#   (149): ParameterModule()
#   (150): Identity()
#   (151): ParameterModule()
#   (152): ParameterModule()
#   (153): Identity()
#   (154): ParameterModule()
#   (155): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (156): MemoryEfficientSwish()
#   (157): Identity()
#   (158): ParameterModule()
#   (159): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (160): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (161): ParameterModule()
#   (162): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (163): Identity()
#   (164): ParameterModule()
#   (165): ParameterModule()
#   (166): Identity()
#   (167): ParameterModule()
#   (168): ParameterModule()
#   (169): Identity()
#   (170): ParameterModule()
#   (171): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (172): MemoryEfficientSwish()
#   (173): Identity()
#   (174): ParameterModule()
#   (175): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (176): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (177): ParameterModule()
#   (178): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (179): Identity()
#   (180): ParameterModule()
#   (181): ParameterModule()
#   (182): Identity()
#   (183): ParameterModule()
#   (184): ParameterModule()
#   (185): Identity()
#   (186): ParameterModule()
#   (187): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (188): MemoryEfficientSwish()
#   (189): Identity()
#   (190): ParameterModule()
#   (191): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (192): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (193): ParameterModule()
#   (194): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (195): Identity()
#   (196): ParameterModule()
#   (197): ParameterModule()
#   (198): Identity()
#   (199): ParameterModule()
#   (200): ParameterModule()
#   (201): Identity()
#   (202): ParameterModule()
#   (203): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (204): MemoryEfficientSwish()
#   (205): Identity()
#   (206): ParameterModule()
#   (207): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (208): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (209): ParameterModule()
#   (210): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (211): Identity()
#   (212): ParameterModule()
#   (213): ParameterModule()
#   (214): Identity()
#   (215): ParameterModule()
#   (216): ParameterModule()
#   (217): Identity()
#   (218): ParameterModule()
#   (219): BatchNorm2d(136, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (220): MemoryEfficientSwish()
#   (221): Identity()
#   (222): ParameterModule()
#   (223): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (224): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (225): ParameterModule()
#   (226): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (227): Identity()
#   (228): ParameterModule()
#   (229): ParameterModule()
#   (230): Identity()
#   (231): ParameterModule()
#   (232): ParameterModule()
#   (233): Identity()
#   (234): ParameterModule()
#   (235): BatchNorm2d(136, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (236): MemoryEfficientSwish()
#   (237): Identity()
#   (238): ParameterModule()
#   (239): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (240): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (241): ParameterModule()
#   (242): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (243): Identity()
#   (244): ParameterModule()
#   (245): ParameterModule()
#   (246): Identity()
#   (247): ParameterModule()
#   (248): ParameterModule()
#   (249): Identity()
#   (250): ParameterModule()
#   (251): BatchNorm2d(136, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (252): MemoryEfficientSwish()
#   (253): Identity()
#   (254): ParameterModule()
#   (255): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (256): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (257): ParameterModule()
#   (258): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (259): Identity()
#   (260): ParameterModule()
#   (261): ParameterModule()
#   (262): Identity()
#   (263): ParameterModule()
#   (264): ParameterModule()
#   (265): Identity()
#   (266): ParameterModule()
#   (267): BatchNorm2d(136, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (268): MemoryEfficientSwish()
#   (269): Identity()
#   (270): ParameterModule()
#   (271): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (272): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (273): ParameterModule()
#   (274): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (275): Identity()
#   (276): ParameterModule()
#   (277): ParameterModule()
#   (278): Identity()
#   (279): ParameterModule()
#   (280): ParameterModule()
#   (281): Identity()
#   (282): ParameterModule()
#   (283): BatchNorm2d(136, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (284): MemoryEfficientSwish()
#   (285): Identity()
#   (286): ParameterModule()
#   (287): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (288): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (289): ParameterModule()
#   (290): BatchNorm2d(816, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (291): Identity()
#   (292): ParameterModule()
#   (293): ParameterModule()
#   (294): Identity()
#   (295): ParameterModule()
#   (296): ParameterModule()
#   (297): Identity()
#   (298): ParameterModule()
#   (299): BatchNorm2d(232, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (300): MemoryEfficientSwish()
#   (301): Identity()
#   (302): ParameterModule()
#   (303): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (304): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (305): ParameterModule()
#   (306): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (307): Identity()
#   (308): ParameterModule()
#   (309): ParameterModule()
#   (310): Identity()
#   (311): ParameterModule()
#   (312): ParameterModule()
#   (313): Identity()
#   (314): ParameterModule()
#   (315): BatchNorm2d(232, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (316): MemoryEfficientSwish()
#   (317): Identity()
#   (318): ParameterModule()
#   (319): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (320): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (321): ParameterModule()
#   (322): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (323): Identity()
#   (324): ParameterModule()
#   (325): ParameterModule()
#   (326): Identity()
#   (327): ParameterModule()
#   (328): ParameterModule()
#   (329): Identity()
#   (330): ParameterModule()
#   (331): BatchNorm2d(232, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (332): MemoryEfficientSwish()
#   (333): Identity()
#   (334): ParameterModule()
#   (335): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (336): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (337): ParameterModule()
#   (338): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (339): Identity()
#   (340): ParameterModule()
#   (341): ParameterModule()
#   (342): Identity()
#   (343): ParameterModule()
#   (344): ParameterModule()
#   (345): Identity()
#   (346): ParameterModule()
#   (347): BatchNorm2d(232, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (348): MemoryEfficientSwish()
#   (349): Identity()
#   (350): ParameterModule()
#   (351): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (352): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (353): ParameterModule()
#   (354): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (355): Identity()
#   (356): ParameterModule()
#   (357): ParameterModule()
#   (358): Identity()
#   (359): ParameterModule()
#   (360): ParameterModule()
#   (361): Identity()
#   (362): ParameterModule()
#   (363): BatchNorm2d(232, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (364): MemoryEfficientSwish()
#   (365): Identity()
#   (366): ParameterModule()
#   (367): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (368): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (369): ParameterModule()
#   (370): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (371): Identity()
#   (372): ParameterModule()
#   (373): ParameterModule()
#   (374): Identity()
#   (375): ParameterModule()
#   (376): ParameterModule()
#   (377): Identity()
#   (378): ParameterModule()
#   (379): BatchNorm2d(232, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (380): MemoryEfficientSwish()
#   (381): Identity()
#   (382): ParameterModule()
#   (383): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (384): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (385): ParameterModule()
#   (386): BatchNorm2d(1392, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (387): Identity()
#   (388): ParameterModule()
#   (389): ParameterModule()
#   (390): Identity()
#   (391): ParameterModule()
#   (392): ParameterModule()
#   (393): Identity()
#   (394): ParameterModule()
#   (395): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (396): MemoryEfficientSwish()
#   (397): Identity()
#   (398): ParameterModule()
#   (399): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (400): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (401): ParameterModule()
#   (402): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (403): Identity()
#   (404): ParameterModule()
#   (405): ParameterModule()
#   (406): Identity()
#   (407): ParameterModule()
#   (408): ParameterModule()
#   (409): Identity()
#   (410): ParameterModule()
#   (411): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (412): MemoryEfficientSwish()
#   (413): Identity()
#   (414): ParameterModule()
#   (415): BatchNorm2d(1536, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (416): AdaptiveAvgPool2d(output_size=1)
#   (417): Dropout(p=0.3, inplace=False)
#   (418): Linear(in_features=1536, out_features=14, bias=True)
#   (419): MemoryEfficientSwish()
# )], add_time=True, silent=False)

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>Cardiomegaly-AUC</th>
#       <th>Edema-AUC</th>
#       <th>Consolidation-AUC</th>
#       <th>Atelectasis-AUC</th>
#       <th>Pleural Effusion-AUC</th>
#       <th>micro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='87' class='' max='27926', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.31% [87/27926 01:40<8:56:38 1.0497]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(3*1e-4))
learn.save(EXP+'-stage-1')
learn.recorder.plot_losses()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>Cardiomegaly-AUC</th>
#       <th>Edema-AUC</th>
#       <th>Consolidation-AUC</th>
#       <th>Atelectasis-AUC</th>
#       <th>Pleural Effusion-AUC</th>
#       <th>micro-AUC</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='262' class='' max='27926', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.94% [262/27926 06:10<10:52:51 0.4050]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-718d9f0078a6> in <module>
#       1 learn.unfreeze()
# ----> 2 learn.fit_one_cycle(2, max_lr=slice(3*1e-4))
#       3 learn.save(EXP+'-stage-1')
#       4 learn.recorder.plot_losses()
#
# ~/.conda/envs/venv/lib/python3.6/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      21     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      22                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 23     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      24
#      25 def fit_fc(learn:Learner, tot_epochs:int=1, lr:float=defaults.lr,  moms:Tuple[float,float]=(0.95,0.85), start_pct:float=0.72,
#
# ~/.conda/envs/venv/lib/python3.6/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/.conda/envs/venv/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      97             cb_handler.set_dl(learn.data.train_dl)
#      98             cb_handler.on_epoch_begin()
# ---> 99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
#     101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#
# ~/.conda/envs/venv/lib/python3.6/site-packages/fastprogress/fastprogress.py in __iter__(self)
#      39         if self.total != 0: self.update(0)
#      40         try:
# ---> 41             for i,o in enumerate(self.gen):
#      42                 if i >= self.total: break
#      43                 yield o
#
# ~/.conda/envs/venv/lib/python3.6/site-packages/fastai/basic_data.py in __iter__(self)
#      73     def __iter__(self):
#      74         "Process and returns items from `DataLoader`."
# ---> 75         for b in self.dl: yield self.proc_batch(b)
#      76
#      77     @classmethod
#
# ~/.conda/envs/venv/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     802
#     803             assert not self._shutdown and self._tasks_outstanding > 0
# --> 804             idx, data = self._get_data()
#     805             self._tasks_outstanding -= 1
#     806
#
# ~/.conda/envs/venv/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#     759         elif self._pin_memory:
#     760             while self._pin_memory_thread.is_alive():
# --> 761                 success, data = self._try_get_data()
#     762                 if success:
#     763                     return data
#
# ~/.conda/envs/venv/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     722         #   (bool: whether successfully get data, any: data if successful else None)
#     723         try:
# --> 724             data = self._data_queue.get(timeout=timeout)
#     725             return (True, data)
#     726         except Exception as e:
#
# ~/.conda/envs/venv/lib/python3.6/queue.py in get(self, block, timeout)
#     171                     if remaining <= 0.0:
#     172                         raise Empty
# --> 173                     self.not_empty.wait(remaining)
#     174             item = self._get()
#     175             self.not_full.notify()
#
# ~/.conda/envs/venv/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
learn.lr_find()
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-5,3*1e-5))
learn.recorder.plot_losses()
learn.save(EXP+'-stage-2')

# %%
learn = cnn_learner(data, models.vgg19_bn, metrics=[acc_02, AUC(pick=1), AUC(pick=2), AUC(pick=3), AUC(pick=4), AUC(pick=5), AUC(pick='micro', plot_auc=True, plot_path=RES_DIR+'valid_ROC_AUC.png')])
learn.load('fastai-vgg-320-u0-stage-2')

# %%
learn.validate(data.valid_dl)

# %%
learn.validate??
